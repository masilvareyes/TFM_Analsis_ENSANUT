# %%
import pandas as pd

# Cargar el dataset
file_path = 'ensadul2021SelcolClustered.csv'
data = pd.read_csv(file_path, sep=';')

# Visualizar las primeras filas y la información del DataFrame
data_head = data.head()
data_info = data.info()

data_head, data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5745 entries, 0 to 5744
# Data columns (total 50 columns):
#  #   Column                                                                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                                                                             --------------  -----
#  0   Folio                                                                                                                                                                              5745 non-null   object
#  1   Folio de integrante                                                                                                                                                                5745 non-null   object
#  2   Region o zona de trabajo                                                                                                                                                           5745 non-null   object
#  3   DESC_ENT                                                                                                                                                                           5745 non-null   object
#  4   Edad del Seleccionado                                                                                                                                                              5745 non-null   int64
#  5   ASEXO ¿Cuál es el sexo de (NOMBRE) ?                                                                                                                                               5745 non-null   object
#  6   ¿Qué edad tenía cuando le diagnosticaron obesidad?                                                                                                                                 5745 non-null   object
#  7   Durante la última semana...¿Sentía como si no pudiera quitarse de encima la tristeza?                                                                                              5745 non-null   object
#  8   Durante la última semana...¿se sintió deprimido/a?                                                                                                                                 5745 non-null   object
#  9   Durante la última semana...¿no durmió bien?                                                                                                                                        5745 non-null   object
#  10  ¿Algún médico le ha dicho que tiene diabetes (o alta el azúcar en la sangre)?                                                                                                      5745 non-null   object
#  11  ¿Algún médico le ha dicho que tiene la presión alta?                                                                                                                               5745 non-null   object
#  12  ¿Le ha dicho el médico que usted tiene (o tuvo) un infarto o ataque al corazón?                                                                                                    5745 non-null   object
#  13  ¿Algún médico le ha dicho que tiene el colesterol alto?                                                                                                                            5745 non-null   object
#  14  ¿Algún médico le ha dicho que tiene los triglicéridos  altos?                                                                                                                      5745 non-null   object
#  15  ¿Su PADRE tiene o tuvo diabetes o azúcar alta en la sangre?                                                                                                                        5745 non-null   object
#  16  ¿Su PADRE tiene o tuvo hipertensión o presión alta?                                                                                                                                5745 non-null   object
#  17  ¿Su PADRE tuvo valores altos de colesterol y/o triglicéridos?                                                                                                                      5745 non-null   object
#  18  ¿Su MADRE tiene o tuvo diabetes o azúcar alta en la sangre?                                                                                                                        5745 non-null   object
#  19  ¿Su MADRE tiene o tuvo hipertensión o presión alta?                                                                                                                                5745 non-null   object
#  20  ¿Su MADRE tuvo valores altos de colesterol y/o triglicéridos?                                                                                                                      5745 non-null   object
#  21  A1005F ¿Qué diagnóstico le dieron?                                                                                                                                                 5745 non-null   object
#  22  A1005G ¿Qué diagnóstico le dieron?                                                                                                                                                 5745 non-null   object
#  23  A1005H ¿Qué diagnóstico le dieron?                                                                                                                                                 5745 non-null   object
#  24  A1005I ¿Qué diagnóstico le dieron?                                                                                                                                                 5745 non-null   object
#  25  A1001I i) detección de colesterol o triglicéridos altos (examen de sangre)?                                                                                                        5745 non-null   object
#  26  A1005I ¿Qué diagnóstico le dieron?.1                                                                                                                                               5745 non-null   object
#  27  A1211 ¿Alguna vez ha pensado en suicidarse?                                                                                                                                        5745 non-null   object
#  28  A1301 Actualmente, ¿fuma tabaco…                                                                                                                                                   5745 non-null   object
#  29  A1308 En los últimos 12 meses,¿Con qué frecuencia tomó al menos una copa ya sea de vino, cerveza, whisky o cualquier otra bebida que contenga alcohol?                             5745 non-null   object
#  30  A1405 ¿Tiene dificultad para caminar o subir escalones?                                                                                                                            5745 non-null   object
#  31  A1407 ¿Tiene dificultad para el cuidado propio, tal como lavarse todo el cuerpo o vestirse?                                                                                        5745 non-null   object
#  32  A1408 Usando su idioma habitual, ¿tiene dificultad para comunicarse, por ejemplo, entender a otros o hacerse entender?                                                             5745 non-null   object
#  33  A1409 Durante los últimos 7 días, ¿Cuántos días usted caminó por lo menos 10 minutos seguidos? Solo para trasladarse de un lugar a otro                                            5745 non-null   int64
#  34  A1412 Durante los últimos 7 días, ¿Cuántos días usted caminó por lo menos 10 minutos seguidos?                                                                                     5745 non-null   int64
#  35  A1414 Entonces, ¿el tiempo que paso usted caminando, solo por recreación, deporte, ejercicio o placer,  durante los últimos ____ días es de aproximadamente ___ (horas/ minutos)?  5745 non-null   object
#  36  A1507 ¿A cuántos de sus familiares siente lo suficientemente cercanos como para llamarlos cuando necesita ayuda?                                                                   5745 non-null   object
#  37  A1510 A cuántos de sus amigos siente lo suficientemente cercanos como para llamarlos cuando necesita ayuda?                                                                        5745 non-null   object
#  38  A1514 ¿Con qué frecuencia siente que le falta compañía?                                                                                                                            5745 non-null   object
#  39  A1515 ¿Con qué frecuencia se siente excluido?                                                                                                                                      5745 non-null   object
#  40  A1516 ¿Con qué frecuencia se siente aislado de los demás?                                                                                                                          5745 non-null   object
#  41  Estrato urbanidad/ruralidad                                                                                                                                                        5745 non-null   object
#  42  Region                                                                                                                                                                             5745 non-null   object
#  43  INT_H0317A ¿Cuál es el último año o grado que aprobó (USTED/NOMBRE) en la escuela? NIVEL                                                                                           5745 non-null   object
#  44  INT_H0903 ¿USTED/NOMBRE realizaba algún deporte o actividad física antes de la pandemia por COVID-19?                                                                              5745 non-null   object
#  45  INT_H0905 En comparación al tiempo que pasaba sentado(a) o reclinado(a) de forma habitual antes de la pandemia por COVID-19, actualmente este tiempo…                              5745 non-null   object
#  46  ALTURA_NUM                                                                                                                                                                         5745 non-null   float64
#  47  PESO_NUM                                                                                                                                                                           5745 non-null   int64
#  48  IMC                                                                                                                                                                                5745 non-null   float64
#  49  Cluster                                                                                                                                                                            5745 non-null   int64
# dtypes: float64(2), int64(5), object(43)
# memory usage: 2.2+ MB
# (           Folio Folio de integrante Region o zona de trabajo  \
#  0  2021_01001019    2021_01001019_02             Centro_Norte
#  1  2021_01001019    2021_01001019_03             Centro_Norte
#  2  2021_01001021    2021_01001021_02             Centro_Norte
#  3  2021_01001031    2021_01001031_04             Centro_Norte
#  4  2021_01001105    2021_01001105_03             Centro_Norte
#
#              DESC_ENT  Edad del Seleccionado  \
#  0  01 AGUASCALIENTES                     42
#  1  01 AGUASCALIENTES                     21
#  2  01 AGUASCALIENTES                     48
#  3  01 AGUASCALIENTES                     24
#  4  01 AGUASCALIENTES                     42
#
#    ASEXO ¿Cuál es el sexo de (NOMBRE) ?  \
#  0                                Mujer
#  1                               Hombre
#  2                               Hombre
#  3                                Mujer
#  4                                Mujer
#
#    ¿Qué edad tenía cuando le diagnosticaron obesidad?  \
#  0
#  1
#  2
#  3
#  4
#
#    Durante la última semana...¿Sentía como si no pudiera quitarse de encima la tristeza?  \
#  0                Rara vez o nunca (menos de un día).
#  1                Rara vez o nunca (menos de un día).
#  2                Rara vez o nunca (menos de un día).
#  3               Pocas veces o alguna vez (1-2 días).
#  4                Rara vez o nunca (menos de un día).
#
#    Durante la última semana...¿se sintió deprimido/a?  \
#  0                Rara vez o nunca (menos de un día).
#  1                Rara vez o nunca (menos de un día).
#  2                Rara vez o nunca (menos de un día).
#  3               Pocas veces o alguna vez (1-2 días).
#  4                Rara vez o nunca (menos de un día).
#
#           Durante la última semana...¿no durmió bien?  ...  \
#  0  Todo el tiempo o la mayoría del tiempo    (5-7...  ...
#  1               Pocas veces o alguna vez (1-2 días).  ...
#  2                Rara vez o nunca (menos de un día).  ...
#  3               Pocas veces o alguna vez (1-2 días).  ...
#  4                Rara vez o nunca (menos de un día).  ...
#
#    A1516 ¿Con qué frecuencia se siente aislado de los demás?  \
#  0
#  1
#  2
#  3
#  4
#
#        Estrato urbanidad/ruralidad              Region  \
#  0  Metropolitano (100mil y + Hab)  Resto Centro Norte
#  1  Metropolitano (100mil y + Hab)  Resto Centro Norte
#  2  Metropolitano (100mil y + Hab)  Resto Centro Norte
#  3  Metropolitano (100mil y + Hab)  Resto Centro Norte
#  4  Metropolitano (100mil y + Hab)  Resto Centro Norte
#
#    INT_H0317A ¿Cuál es el último año o grado que aprobó (USTED/NOMBRE) en la escuela? NIVEL  \
#  0                         Licenciatura o profesional
#  1                         Licenciatura o profesional
#  2                         Licenciatura o profesional
#  3                         Licenciatura o profesional
#  4                        Preparatoria o Bachillerato
#
#    INT_H0903 ¿USTED/NOMBRE realizaba algún deporte o actividad física antes de la pandemia por COVID-19?  \
#  0                                                 No
#  1                                                 No
#  2                                                 Sí
#  3                                                 No
#  4                                                 No
#
#    INT_H0905 En comparación al tiempo que pasaba sentado(a) o reclinado(a) de forma habitual antes de la pandemia por COVID-19, actualmente este tiempo…  \
#  0                                         fue igual?
#  1                                         fue igual?
#  2                                         disminuyó?
#  3                                         disminuyó?
#  4                                         disminuyó?
#
#    ALTURA_NUM PESO_NUM        IMC Cluster
#  0      160.2       64  24.937617       5
#  1      171.5       70  23.799607       0
#  2      164.3       78  28.894786       0
#  3      159.7       72  28.230766       3
#  4      163.0       92  34.626821       4
#
#  [5 rows x 50 columns],
#  None)

# %%
# Convertir las columnas de interés a tipos de datos adecuados para el análisis
data['IMC'] = pd.to_numeric(data['IMC'], errors='coerce')
data['Cluster'] = pd.to_numeric(data['Cluster'], errors='coerce')

# Eliminar posibles valores nulos en las columnas de IMC y Cluster
data_clean = data.dropna(subset=['IMC', 'Cluster'])

# Calcular el promedio de IMC por cluster
average_imc_per_cluster = data_clean.groupby('Cluster')['IMC'].mean().sort_values(ascending=False)

average_imc_per_cluster
# Out:
# Cluster
# 6     31.376853
# 7     30.333217
# 5     30.160493
# 1     28.889835
# 8     28.778496
# 4     28.742355
# 10    28.423762
# 2     27.775829
# 0     27.320749
# 9     26.786451
# 3     26.725028
# Name: IMC, dtype: float64

# %%
# Identificar clusters con obesidad (IMC promedio >= 30)
clusters_with_obesity = average_imc_per_cluster[average_imc_per_cluster >= 30]

clusters_with_obesity
# Out:
# Cluster
# 6    31.376853
# 7    30.333217
# 5    30.160493
# Name: IMC, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Colores para el gráfico: rojo para clusters con obesidad, azul para los demás
colors = ['blue']

# Crear el gráfico de barras con colores personalizados
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(x=average_imc_per_cluster.index, y=average_imc_per_cluster.values, palette=colors)
plt.title('Promedio de IMC por Cluster (Obesidad Resaltada)', fontsize=16)
plt.xlabel('Cluster', fontsize=14)
plt.ylabel('Promedio de IMC', fontsize=14)
plt.xticks(rotation=45)


# Resaltar en rojo los clusters con obesidad
for i, bar in enumerate(bar_plot.patches):
    if i in clusters_with_obesity.index:
        bar.set_color('red')


plt.show()

# %%
# Aislar el Cluster 6 en un nuevo dataset
cluster_6_data = data_clean[data_clean['Cluster'] == 6]

# Verificando las primeras filas del nuevo dataset
cluster_6_head = cluster_6_data.head()

cluster_6_head
# Out:
#              Folio Folio de integrante Region o zona de trabajo  \
# 33   2021_02006017    2021_02006017_02           Pacifico_Norte
# 38   2021_03001027    2021_03001027_02           Pacifico_Norte
# 59   2021_03003017    2021_03003017_02           Pacifico_Norte
# 81   2021_03008002    2021_03008002_02           Pacifico_Norte
# 159  2021_04004014    2021_04004014_01                Península
#
#                    DESC_ENT  Edad del Seleccionado  \
# 33       02 BAJA CALIFORNIA                     39
# 38   03 BAJA CALIFORNIA SUR                     53
# 59   03 BAJA CALIFORNIA SUR                     42
# 81   03 BAJA CALIFORNIA SUR                     41
# 159             04 CAMPECHE                     55
#
#     ASEXO ¿Cuál es el sexo de (NOMBRE) ?  \
# 33                                 Mujer
# 38                                 Mujer
# 59                                 Mujer
# 81                                 Mujer
# 159                               Hombre
#
#     ¿Qué edad tenía cuando le diagnosticaron obesidad?  \
# 33                                                  30
# 38                                                  49
# 59                                                  20
# 81
# 159
#
#     Durante la última semana...¿Sentía como si no pudiera quitarse de encima la tristeza?  \
# 33                 Rara vez o nunca (menos de un día).
# 38                 Rara vez o nunca (menos de un día).
# 59        Un número de veces conside-rable (3-4 dias).
# 81                Pocas veces o alguna vez (1-2 días).
# 159                Rara vez o nunca (menos de un día).
#
#     Durante la última semana...¿se sintió deprimido/a?  \
# 33                 Rara vez o nunca (menos de un día).
# 38                 Rara vez o nunca (menos de un día).
# 59        Un número de veces conside-rable (3-4 dias).
# 81                 Rara vez o nunca (menos de un día).
# 159                Rara vez o nunca (menos de un día).
#
#       Durante la última semana...¿no durmió bien?  ...  \
# 33           Pocas veces o alguna vez (1-2 días).  ...
# 38            Rara vez o nunca (menos de un día).  ...
# 59   Un número de veces conside-rable (3-4 dias).  ...
# 81   Un número de veces conside-rable (3-4 dias).  ...
# 159           Rara vez o nunca (menos de un día).  ...
#
#     A1516 ¿Con qué frecuencia se siente aislado de los demás?  \
# 33
# 38
# 59
# 81
# 159
#
#         Estrato urbanidad/ruralidad          Region  \
# 33        Urbano ( 2500-99,999 Hab)  Pacifico-Norte
# 38        Urbano ( 2500-99,999 Hab)  Pacifico-Norte
# 59   Metropolitano (100mil y + Hab)  Pacifico-Norte
# 81   Metropolitano (100mil y + Hab)  Pacifico-Norte
# 159       Urbano ( 2500-99,999 Hab)       Península
#
#     INT_H0317A ¿Cuál es el último año o grado que aprobó (USTED/NOMBRE) en la escuela? NIVEL  \
# 33                                          Secundaria
# 38                                            Primaria
# 59                                            Primaria
# 81                                          Secundaria
# 159                        Preparatoria o Bachillerato
#
#     INT_H0903 ¿USTED/NOMBRE realizaba algún deporte o actividad física antes de la pandemia por COVID-19?  \
# 33                                                  No
# 38                                                  No
# 59                                                  No
# 81                                                  No
# 159                                                 Sí
#
#     INT_H0905 En comparación al tiempo que pasaba sentado(a) o reclinado(a) de forma habitual antes de la pandemia por COVID-19, actualmente este tiempo…  \
# 33                                          fue igual?
# 38                                            aumentó?
# 59                                          fue igual?
# 81                                          fue igual?
# 159                                           aumentó?
#
#     ALTURA_NUM PESO_NUM        IMC Cluster
# 33       154.8       76  31.715509       6
# 38       145.5       69  32.592907       6
# 59       171.1      120  40.990312       6
# 81       155.1       79  32.840026       6
# 159      158.6       68  27.033517       6
#
# [5 rows x 50 columns]

# %%
# Cargar el nuevo dataset normalizado
file_path_normalized = 'ensadul2021_Clustered.csv'
data_normalized = pd.read_csv(file_path_normalized, sep=';')

# Convertir la columna 'Cluster' a tipo numérico y aislar el Cluster 6
data_normalized['Cluster'] = pd.to_numeric(data_normalized['Cluster'], errors='coerce')
cluster_6_normalized = data_normalized[data_normalized['Cluster'] == 6]

# Verificar las primeras filas del nuevo dataset normalizado para el Cluster 6
cluster_6_normalized_head = cluster_6_normalized.head()

cluster_6_normalized_head
# Out:
#      Region o zona de trabajo  DESC_ENT  Edad del Seleccionado  \
# 33                          1         2                     39
# 38                          1         3                     53
# 59                          1         3                     42
# 81                          1         3                     41
# 159                         9         4                     55
#
#      ASEXO ¿Cuál es el sexo de (NOMBRE) ?  \
# 33                                      2
# 38                                      2
# 59                                      2
# 81                                      2
# 159                                     1
#
#      Durante la última semana...¿Sentía como si no pudiera quitarse de encima la tristeza?  \
# 33                                                 1.0
# 38                                                 1.0
# 59                                                 1.0
# 81                                                 2.0
# 159                                                1.0
#
#      Durante la última semana...¿se sintió deprimido/a?  \
# 33                                                 1.0
# 38                                                 1.0
# 59                                                 1.0
# 81                                                 1.0
# 159                                                1.0
#
#      Durante la última semana...¿no durmió bien?  \
# 33                                           2.0
# 38                                           1.0
# 59                                           1.0
# 81                                           1.0
# 159                                          1.0
#
#      A1405 ¿Tiene dificultad para caminar o subir escalones?  \
# 33                                                   1
# 38                                                   1
# 59                                                   2
# 81                                                   1
# 159                                                  1
#
#      A1407 ¿Tiene dificultad para el cuidado propio, tal como lavarse todo el cuerpo o vestirse?  \
# 33                                                 1.0
# 38                                                 1.0
# 59                                                 1.0
# 81                                                 1.0
# 159                                                1.0
#
#      A1408 Usando su idioma habitual, ¿tiene dificultad para comunicarse, por ejemplo, entender a otros o hacerse entender?  \
# 33                                                   1
# 38                                                   1
# 59                                                   1
# 81                                                   1
# 159                                                  1
#
#      ...  Region_Guanajuato  Region_Pacifico-Norte  Region_Pacífico Sur  \
# 33   ...                  0                      1                    0
# 38   ...                  0                      1                    0
# 59   ...                  0                      1                    0
# 81   ...                  0                      1                    0
# 159  ...                  0                      0                    0
#
#      Region_Pacífico-Centro  Region_Península  Region_Resto Centro Norte  \
# 33                        0                 0                          0
# 38                        0                 0                          0
# 59                        0                 0                          0
# 81                        0                 0                          0
# 159                       0                 1                          0
#
#      INT_H0905 En comparación al tiempo que pasaba sentado(a) o reclinado(a) de forma habitual antes de la pandemia por COVID-19, actualmente este tiempo…_aumentó?  \
# 33                                                   0
# 38                                                   1
# 59                                                   0
# 81                                                   0
# 159                                                  1
#
#      INT_H0905 En comparación al tiempo que pasaba sentado(a) o reclinado(a) de forma habitual antes de la pandemia por COVID-19, actualmente este tiempo…_disminuyó?  \
# 33                                                   0
# 38                                                   0
# 59                                                   0
# 81                                                   0
# 159                                                  0
#
#      INT_H0905 En comparación al tiempo que pasaba sentado(a) o reclinado(a) de forma habitual antes de la pandemia por COVID-19, actualmente este tiempo…_fue igual?  \
# 33                                                   1
# 38                                                   0
# 59                                                   1
# 81                                                   1
# 159                                                  0
#
#      Cluster
# 33         6
# 38         6
# 59         6
# 81         6
# 159        6
#
# [5 rows x 90 columns]

# %%
import numpy as np

# Filtrar el dataset para incluir solo las columnas numéricas
numeric_data = cluster_6_normalized.select_dtypes(include=[np.number])

# Calcular la matriz de correlación
correlation_matrix = numeric_data.corr()

# Crear el mapa de calor de correlación
plt.figure(figsize=(22, 20))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', linewidths=.5)
plt.title('Mapa de Calor de Correlación - Cluster 6', fontsize=16)
plt.show()

# %%
# Guardar la matriz de correlación en un archivo CSV
csv_file_path = 'cluster_6_correlation_matrix.csv'
correlation_matrix.to_csv(csv_file_path)

csv_file_path
# Out:
# 'cluster_6_correlation_matrix.csv'

# %%
# Extraer las correlaciones del IMC con las demás variables
imc_correlations = correlation_matrix['IMC']

# Ordenar las correlaciones de mayor a menor (en valor absoluto) para identificar las más fuertes
imc_correlations_sorted = imc_correlations.abs().sort_values(ascending=False)

imc_correlations_sorted.head(10)
# Out:
# IMC                                                                               1.000000
# PESO_NUM                                                                          0.693892
# ALTURA_NUM                                                                        0.384091
# ¿Algún médico le ha dicho que tiene la presión alta?_SI                           0.251772
# ¿Algún médico le ha dicho que tiene la presión alta?_NO                           0.251772
# A1001I i) detección de colesterol o triglicéridos altos (examen de sangre)?_NO    0.224544
# A1005F ¿Qué diagnóstico le dieron?_                                               0.195792
# A1001I i) detección de colesterol o triglicéridos altos (examen de sangre)?_      0.167615
# Region_Pacífico-Centro                                                            0.164671
# A1005F ¿Qué diagnóstico le dieron?_Positivo                                       0.155788
# Name: IMC, dtype: float64

# %%
# Filtrar las correlaciones por aquellas mayores a 0.30 o menores a -0.30
significant_correlations = imc_correlations[(imc_correlations > 0.10) | (imc_correlations < -0.10)]

# Ordenar las correlaciones filtradas
significant_correlations_sorted = significant_correlations.sort_values(ascending=False)

# Convertir a formato de tabla (DataFrame)
significant_correlations_table = significant_correlations_sorted.reset_index()
significant_correlations_table.columns = ['Variable', 'Correlación con IMC']

significant_correlations_table
# Out:
#                                              Variable  Correlación con IMC
# 0                                                 IMC             1.000000
# 1                                            PESO_NUM             0.693892
# 2   ¿Algún médico le ha dicho que tiene la presión...             0.251772
# 3   A1001I i) detección de colesterol o triglicéri...             0.224544
# 4                              Region_Pacífico-Centro             0.164671
# 5         A1005F ¿Qué diagnóstico le dieron?_Positivo             0.155788
# 6                ASEXO ¿Cuál es el sexo de (NOMBRE) ?             0.136403
# 7                               Region_Pacifico-Norte             0.127652
# 8   ¿Su PADRE tiene o tuvo hipertensión o presión ...             0.126788
# 9   A1005F ¿Qué diagnóstico le dieron?_Bien o Nega...             0.123063
# 10  ¿Su MADRE tiene o tuvo diabetes o azúcar alta ...             0.118856
# 11  ¿Su PADRE tuvo valores altos de colesterol y/o...             0.101168
# 12  INT_H0905 En comparación al tiempo que pasaba ...             0.100336
# 13  ¿Su PADRE tuvo valores altos de colesterol y/o...            -0.101168
# 14  A1308 En los últimos 12 meses,¿Con qué frecuen...            -0.109875
# 15  ¿Su MADRE tiene o tuvo diabetes o azúcar alta ...            -0.118856
# 16  ¿Su PADRE tiene o tuvo hipertensión o presión ...            -0.126788
# 17  ¿Le ha dicho el médico que usted tiene (o tuvo...            -0.128119
# 18  A1001I i) detección de colesterol o triglicéri...            -0.167615
# 19                A1005F ¿Qué diagnóstico le dieron?_            -0.195792
# 20  ¿Algún médico le ha dicho que tiene la presión...            -0.251772
# 21                                         ALTURA_NUM            -0.384091
